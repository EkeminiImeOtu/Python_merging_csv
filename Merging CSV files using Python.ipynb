# %%
import os
import glob
import pandas as pd
os.chdir("C:\\Users\\USER\\Documents\\work\\new_data")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
combined_csv.tail()
# Out:
#       Supplier_Product_Number                  Supplier_Product_Details  \
# 19995                     460     Environmentally Preferred• Latex Free
# 19996             70071660271  Impact Standardization• Support Services
# 19997             70071660537  Impact Standardization• Support Services
# 19998             75040055362  Impact Standardization• Support Services
# 19999             70071659943  Impact Standardization• Support Services
#
#           My_Price     Contracted_Supplier  \
# 19995  $1,036.8500  Lakeside Manufacturing
# 19996          NaN              3M Company
# 19997          NaN              3M Company
# 19998          NaN              3M Company
# 19999          NaN              3M Company
#
#                                              Description Contract_Number  \
# 19995        Cart Multishelf 4 Shelf Edges Down 21X50 in          CE2903
# 19996  Tape Safety W24inXL60ft Black/Yellow Stripe 61...          FM0331
# 19997  Cleaner Carpet 0.5gal Pretreatment Concentrate...          FM0331
# 19998       Pad Scouring Dual Purpose 96HEX Scotch-Brite          FM0331
# 19999  CLEANER GENERAL PURPOSE LIQUID 0.5 GAL JUG CON...          FM0331
#
#                      Contract_Number_Details        Contract_price  \
# 19995               Lakeside Carts & Shelves  $1,036.8500\nExpired
# 19996  3M Housekeeping and Laundry Chemicals             $353.9858
# 19997  3M Housekeeping and Laundry Chemicals              $84.3400
# 19998  3M Housekeeping and Laundry Chemicals               $5.6500
# 19999  3M Housekeeping and Laundry Chemicals             $101.6300
#
#          MY_Price2 Contracted_UOM  \
# 19995  $1,036.8500             EA
# 19996          NaN             CA
# 19997          NaN             CA
# 19998          NaN             CA
# 19999          NaN             CA
#
#                                             Original_URL
# 19995  https://catalog.vizientinc.com/search/product?...
# 19996  https://catalog.vizientinc.com/search/product?...
# 19997  https://catalog.vizientinc.com/search/product?...
# 19998  https://catalog.vizientinc.com/search/product?...
# 19999  https://catalog.vizientinc.com/search/product?...

# %%
combined_csv.to_csv( "new_combined.csv", index=False, encoding='utf-8-sig')
